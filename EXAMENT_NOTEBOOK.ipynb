# %% [markdown]
# # import of packages and verification of plotly version

# %%
import plotly 
from plotly import __version__
print(__version__)
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# Out:
# 5.9.0

# %%
import plotly as py
import plotly.graph_objs as go
import pandas  as pd

# %%
# diagrame circulaire

# %%
troiseve= pd.read_csv("C:\\Users\\LENOVO\Desktop\\MASTER_DIT\Python for data scientistes\\exament\\Classeur3bfinsecurité.csv", sep=";")

# %%
troiseve.head()
# Out:
#      region  climatique  economique  insecurite
# 0  Cascades           3           5          11
# 1       Est          15          14          14
# 2     Sahel          18          12          15

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
labels = ["Cascades", "Est", "Sahel"]
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])
fig.add_trace(go.Pie(labels=labels, values=troiseve["climatique"],
               name="climatique"), 1, 1)
fig.add_trace(go.Pie(labels=labels, values=troiseve["insecurite"],  
            name="insecurite"),1, 2)
fig.update_traces(hole=.4, hoverinfo="label+percent+name")
fig.update_layout(
    title_text="Deux grands événements qui ont impacté la vie des familles selon les trois region au Burkina Faso",
    annotations=[dict(text='climatique', x=0.16, y=0.5, font_size=20, showarrow=False),
                dict(text='insécurité', x=0.84, y=0.5, font_size=20, showarrow=False)])
fig.show()
# Out:
# <div>                            <div id="8fe21b1c-d183-4265-8ecc-0b31f9b7a206" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fe21b1c-d183-4265-8ecc-0b31f9b7a206")) {                    Plotly.newPlot(                        "8fe21b1c-d183-4265-8ecc-0b31f9b7a206",                        [{"labels":["Cascades","Est","Sahel"],"name":"climatique","values":[3,15,18],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.0,1.0]},"hole":0.4,"hoverinfo":"label+percent+name"},{"labels":["Cascades","Est","Sahel"],"name":"insecurite","values":[11,14,15],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]},"hole":0.4,"hoverinfo":"label+percent+name"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinew
# ...

# %% [markdown]
# # boxplot on the seaborne data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datataxi=sns.load_dataset('taxis')
datataxi.head(2)
#datataxi.shape
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan

# %%
import plotly.express as px

fig = px.violin(datataxi, y =datataxi['fare'], x = datataxi['payment'],color =datataxi['color'],
    box=True, points="all", hover_data=datataxi.columns)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14608\898434089.py in <module>
#       1 import plotly.express as px
#       2
# ----> 3 fig = px.violin(datataxi, y =datataxi['fare'], x = datataxi['payment'],color =datataxi['color'],
#       4     box=True, points="all", hover_data=datataxi.columns)
#       5 fig.show()
#
# NameError: name 'datataxi' is not defined

# %%
### Nuage de point

# %%
#import plotly.express as px
#df = px.data.gapminder()

#fig = px.scatter(df.query("year==2007"), x="gdpPercap", y="lifeExp",
                # size="pop", color="continent",
                # hover_name="country", log_x=True, size_max=60)
#fig.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import plotly.express as px
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country", facet_col="continent",
           log_x=True, size_max=45, range_x=[100,100000], range_y=[25,90])
fig.show()
# Out:
# <div>                            <div id="8f73bfe6-74f1-412c-b615-2906b17a74e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f73bfe6-74f1-412c-b615-2906b17a74e1")) {                    Plotly.newPlot(                        "8f73bfe6-74f1-412c-b615-2906b17a74e1",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>continent=Asia<br>year=1952<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Ta
# ...

# %%
#import plotly.express as px
df = px.data.gapminder()

fig = px.scatter(df.query("year==2007"), x="gdpPercap", y="lifeExp",
         size="pop", color="continent",
                 hover_name="country", log_x=True, size_max=60)

fig.show()
# Out:
# <div>                            <div id="735cfcc4-ff29-4295-a3bd-46a913c238aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("735cfcc4-ff29-4295-a3bd-46a913c238aa")) {                    Plotly.newPlot(                        "735cfcc4-ff29-4295-a3bd-46a913c238aa",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>continent=Asia<br>gdpPercap=%{x}<br>lifeExp=%{y}<br>pop=%{marker.size}<extra></extra>","hovertext":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Taiwan","Thaila
# ...

# %% [markdown]
# # Combined graphical representation of histograms on 4 randomly simulated variables

# %%
import plotly.figure_factory as ff
import numpy as np

x1 = np.random.randn(200) - 2
x2 = np.random.randn(200)
x3 = np.random.randn(200) + 2
x4 = np.random.randn(200) + 4

hist_data = [x1, x2, x3, x4]
group_labels = ['Group 1', 'Group 2', 'Group 3', 'Group 4']

fig = ff.create_distplot(hist_data, group_labels, bin_size=.2)
fig.show()
# Out:
# <div>                            <div id="52a1019e-b131-465d-ba4f-84c17f2be60e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52a1019e-b131-465d-ba4f-84c17f2be60e")) {                    Plotly.newPlot(                        "52a1019e-b131-465d-ba4f-84c17f2be60e",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":"Group 1","marker":{"color":"rgb(31, 119, 180)"},"name":"Group 1","opacity":0.7,"x":[-2.6057862745786897,-2.073571780194357,-1.2352227434489422,-1.8648160591670977,-1.1414666813105003,-3.420297389490975,-2.280410501522174,-2.5313256714430494,-0.2508345121190003,-2.504503387634133,-2.556027577889958,-2.51036692746756,-1.0807884292005094,-2.5243001011965447,-3.0912286939578033,-1.9073687051839965,-3.2
# ...

# %%
# Matrice de correlation de nuage de point sur les donnée de fleur iride

# %%
import plotly.express as px
data_base  = px.data.iris()
fig = px.scatter_matrix(data_base, dimensions=["sepal_width", "sepal_length", "petal_width", "petal_length"], color="species")
fig.show()
# Out:
# <div>                            <div id="b79a1134-a092-4dff-86f8-658e054132da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b79a1134-a092-4dff-86f8-658e054132da")) {                    Plotly.newPlot(                        "b79a1134-a092-4dff-86f8-658e054132da",                        [{"dimensions":[{"axis":{"matches":true},"label":"sepal_width","values":[3.5,3.0,3.2,3.1,3.6,3.9,3.4,3.4,2.9,3.1,3.7,3.4,3.0,3.0,4.0,4.4,3.9,3.5,3.8,3.8,3.4,3.7,3.6,3.3,3.4,3.0,3.4,3.5,3.4,3.2,3.1,3.4,4.1,4.2,3.1,3.2,3.5,3.1,3.0,3.4,3.5,2.3,3.2,3.5,3.8,3.0,3.8,3.2,3.7,3.3]},{"axis":{"matches":true},"label":"sepal_length","values":[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9,5.4,4.8,4.8,4.3,5.8,5.7,5.4,5.1,5.7,5.1,5.4,5.1,4.6,5.1,4.8,5.0,5.0,5.2,5.2,4.7,4.8,5.4,5.2,5.5
# ...
